# %%
import os

root_dir = '/' + os.getcwd().split('/')[1]

# os.chdir('/hpcnfs/techunits/imaging/work/ATTEND/achiodin/image_registration')
os.chdir(root_dir + '/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline')

# %%
# !python3 /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/shared/update_paths.py \
    --input-root-path /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/data \
    --output-root-path /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/output/registered_stitched_images \
    --logs-dir /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/develop/logs \
    --cur-logs-dir /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/develop/logs/current \
    --backup-dir /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/develop/logs/backups \
    --input-ext ".ome.tif" \
    --output-ext ".ome.tif" \
    --output-prefix REG_
# Out:
# ['/Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/data/15-13901_DAPI'] ['/Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/output/registered_stitched_images/15-13901_DAPI']
# ...
#   - /hpcnfs/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/output/registered_stitched_images/15-13901_DAPI

# %%
# !python3 /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/src/register_images.py \
    --cur-logs-dir /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/develop/logs/current/ \
    --root-mappings-dir /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/output/mappings \
    --root-registered_crops-dir /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/output/registered_stitched_images \
    --fixed-image_pattern CYCLE_1 \
    --crop-width-x 500 \
    --crop-width-y 500 \
    --overlap-factor 0.3 \
    --delete-checkpoints True
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/Resources/Python.app/Contents/MacOS/Python: can't open file '/hpcnfs/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/src/register_images.py': [Errno 2] No such file or directory

# %%
root_mappings_dir = root_dir + '/techunits/imaging/work/ATTEND/achiodin/image_registration/output/mappings'
root_registered_crops_dir = root_dir + '/techunits/imaging/work/ATTEND/achiodin/image_registration/output/registered_crops'
registered_stitched_images_dir = root_dir + '/techunits/imaging/work/ATTEND/achiodin/image_registration/output/registered_stitched_images'
cur_input_paths_file = root_dir + '/techunits/imaging/work/ATTEND/achiodin/image_registration/cur_input_paths.txt'
cur_output_paths_file = root_dir + '/techunits/imaging/work/ATTEND/achiodin/image_registration/cur_output_paths.txt'
cur_logs_dir = root_dir + '/techunits/imaging/work/ATTEND/achiodin/image_registration/logs/current'
fixed_image_pattern='CYCLE_1' 
crop_width_x=500 
crop_width_y=500

register_images(cur_logs_dir=cur_logs_dir, root_mappings_dir=root_mappings_dir, root_registered_crops_dir=root_registered_crops_dir,
                fixed_image_pattern=fixed_image_pattern, crop_width_x=crop_width_x, crop_width_y=crop_width_y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 register_images(cur_input_paths_file=cur_input_paths_file, cur_output_paths_file=cur_output_paths_file,
#       2                 root_mappings_dir=root_mappings_dir, root_registered_crops_dir=root_registered_crops_dir,
#       3                 fixed_image_pattern=fixed_image_pattern, crop_width_x=crop_width_x, crop_width_y=crop_width_y)
#
# File /Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration/src/register_image_argparse.py:19, in register_images(cur_input_paths_file, cur_output_paths_file, root_mappings_dir, root_registered_crops_dir, fixed_image_pattern, crop_width_x, crop_width_y, overlap_factor, delete_checkpoints)
#      17 input_paths = read_paths_from_file(cur_input_paths_file)
#      18 output_paths = read_paths_from_file(cur_output_paths_file)
# ...

# %%
os.getcwd()
# Out:
# '/Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline'

# %%
import matplotlib.pyplot as plt
from skimage.io import imread

img = imread('/Volumes/scratch/DIMA/chiodin/repositories/image_registration_pipeline/image_registration/output/registered_stitched_images/15-13901_DAPI/REG_15-13901_DAPI_CD14_ARPC1B_CYCLE_2.ome.tif')
# img = imread('/Volumes/scratch/DIMA/chiodin/repositories/image_registration_pipeline/image_registration/output/registered_stitched_images/15-13901_DAPI/REG_15-13901_DAPI_FOXP3_PDL1_2_CYCLE_3.ome.tif')

fixed_img = imread('/Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/data/15-13901_DAPI/15-13901_DAPI_CD8_CD4_CYCLE_1.ome.tif')

# Display the stitched image
plt.figure(figsize=(10, 10))
plt.imshow(img[:, :, 2], cmap='Reds', alpha=0.8)
# plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
from skimage.io import imread

img = imread('/Volumes/scratch/DIMA/chiodin/repositories/image_registration_pipeline/image_registration/output/registered_stitched_images/15-13901_DAPI/REG_15-13901_DAPI_CD14_ARPC1B_CYCLE_2.ome.tif')
# img = imread('/Volumes/scratch/DIMA/chiodin/repositories/image_registration_pipeline/image_registration/output/registered_stitched_images/15-13901_DAPI/REG_15-13901_DAPI_FOXP3_PDL1_2_CYCLE_3.ome.tif')

fixed_img = imread('/Volumes/techunits/imaging/work/ATTEND/achiodin/image_registration_pipeline/image_registration/data/15-13901_DAPI/15-13901_DAPI_CD8_CD4_CYCLE_1.ome.tif')

# Display the stitched image
plt.figure(figsize=(10, 10))
plt.imshow(img[:, :, 2], cmap='Reds', alpha=0.8)
plt.imshow(fixed_img[:, :, 2], cmap='Greens', alpha=0.4)
# plt.axis('off')

plt.show()

# %%
import matplotlib.pyplot as plt
from skimage.io import imread

img = imread('/Users/alessiochiodin/Documents/Repositories/image_registration_pipeline/image_registration/data/output/2024.07.29_TREN/1_TREN.tiff')
# img = imread('/Volumes/scratch/DIMA/chiodin/repositories/image_registration_pipeline/image_registration/output/registered_stitched_images/15-13901_DAPI/REG_15-13901_DAPI_FOXP3_PDL1_2_CYCLE_3.ome.tif')

# %%
# Display the stitched image
plt.figure(figsize=(10, 10))
plt.imshow(img[:, :, 2], alpha=0.8)
# plt.axis('off')

plt.show()
